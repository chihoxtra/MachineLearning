# %%
import urllib.request, json

with urllib.request.urlopen("http://py4e-data.dr-chuck.net/comments_38324.json") as url:
    data = json.loads(url.read().decode())

total = 0
for item in data['comments']:
    #print('Name', item['name'])
    total = total + item['count']
print(total)
# Out:
# 2308

# %%
import urllib.request, urllib.parse, urllib.error
import json

# Note that Google is increasingly requiring keys
# for this API
serviceurl = 'http://py4e-data.dr-chuck.net/geojson?'

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    url = serviceurl + urllib.parse.urlencode(
        {'address': address})

    print('Retrieving', url)
    uh = urllib.request.urlopen(url)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: South Federal University
# Retrieving http://py4e-data.dr-chuck.net/geojson?address=South+Federal+University
# Retrieved 2101 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "South Federal Boulevard",
#                     "short_name": "S Federal Blvd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "South",
#                     "short_name": "South",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Denver",
#                     "short_name": "Denver",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Denver County",
#                     "short_name": "Denver County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Colorado",
#                     "short_name": "CO",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "S Federal Blvd, Denver, CO, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 39.7133974,
#                         "lng": -105.0209967
#                     },
#                     "southwest": {
#                         "lat": 39.6318008,
#                         "lng": -105.0279356
#                     }
#                 },
#                 "location": {
#                     "lat": 39.6726798,
#                     "lng": -105.0250535
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7133974,
#                         "lng": -105.0209967
#                     },
#                     "southwest": {
#                         "lat": 39.6318008,
#                         "lng": -105.0279356
#                     }
#                 }
#             },
#             "partial_match": true,
#             "place_id": "ChIJJ8oO7_B_bIcR2AlhC8nKlok",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 39.6726798 lng -105.0250535
# S Federal Blvd, Denver, CO, USA
# Enter location: Universidad Nacional Costa Rica
# Retrieving http://py4e-data.dr-chuck.net/geojson?address=Universidad+Nacional+Costa+Rica
# Retrieved 1868 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Universidad Nacional",
#                     "short_name": "UNA",
#                     "types": []
#                 },
#                 {
#                     "long_name": "150",
#                     "short_name": "150",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Nicoya",
#                     "short_name": "Nicoya",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Guanacaste",
#                     "short_name": "Guanacaste",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Costa Rica",
#                     "short_name": "CR",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Universidad Nacional, 150, Nicoya, Costa Rica",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 10.1360069,
#                         "lng": -85.44597379999999
#                     },
#                     "southwest": {
#                         "lat": 10.1336726,
#                         "lng": -85.4474866
#                     }
#                 },
#                 "location": {
#                     "lat": 10.1345309,
#                     "lng": -85.4467445
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 10.1361887302915,
#                         "lng": -85.4453812197085
#                     },
#                     "southwest": {
#                         "lat": 10.1334907697085,
#                         "lng": -85.4480791802915
#                     }
#                 }
#             },
#             "place_id": "ChIJz_mTlK2wn48R4oo7RudD8hI",
#             "types": []
#         }
#     ],
#     "status": "OK"
# }
# lat 10.1345309 lng -85.4467445
# Universidad Nacional, 150, Nicoya, Costa Rica
